# %% [markdown]
# <a id="title_ID"></a>
# # Read the CHEOPS data
# <br>
#
# We are going to show how to read the CHEOPS RAW data and access the relevant information to extract the photometry
#
# ### Table of Contents
# - [Imports](#imports_ID)
# - [The Full-Array image](#FullArray_ID)
# - [The Sub-Array images](#SubArray_ID)
# - [The imagettes](#Imagette_ID)

# %% [markdown]
# ***

# %% [markdown]
# <a id="imports_ID"></a>
# ## Imports
# - *os* for operations related to the Operating System;
# - *glob* for Unix-style pathname pattern matching;
# - *numpy* to handle array functions;
# - *pandas* to handle tables;
# - *scipy* to perform operations on arrays, tables and images;
# - *matplotlib* to plot;
# - *astropy* for astronomy and astrophysics common operations.
#
# Notes: *%matplotlib notebook* allows us to have interactive plots in the notebook. *from IPython.display import display* to display large tables in the notebook

# %%
# %matplotlib notebook

import os
import glob
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as pl
import astropy
import astropy.io.fits

from IPython.display import display

# %% [markdown]
# [Top of Page](#title_ID)

# %% [markdown]
# ***

# %% [markdown]
# # Define the paths to the data

# %% [markdown]
# I am putting automatically the files in a dictionary to be able to change target easily.

# %%
target = "KELT-11"

folder_path = f"../Data/{target}"

path2files = {}
for filetype in ["FullArray", "Imagette", "SubArray"]:
    res = glob.glob(os.path.join(folder_path, f"*{filetype}*"))
    if len(res) == 0:
        raise ValueError(f"File {filetype} not found !")
    else:
        path2files[filetype] = res[0]
        
print(path2files)
# Out:
# {'FullArray': '../Data/KELT-11/CH_PR300024_TG000101_TU2020-03-09T14-49-43_SCI_RAW_FullArray_V0101.fits', 'Imagette': '../Data/KELT-11/CH_PR300024_TG000101_TU2020-03-09T14-50-33_SCI_RAW_Imagette_V0101.fits', 'SubArray': '../Data/KELT-11/CH_PR300024_TG000101_TU2020-03-09T14-50-41_SCI_RAW_SubArray_V0101.fits'}

# %% [markdown]
# ***

# %% [markdown]
# <a id="FullArray_ID"></a>
# # The FullArray image
#
# A full Array image which is the image of the full CHEOPS CCD is taken at the beginning of each observations.

# %% [markdown]
# To open [FITS files]() we are going to use the [astropy.io.fits module](https://docs.astropy.org/en/stable/io/fits/) (follow the link for the online documentation).
#
# As you can read there, the "proper" way to open a FITS file is to use a with structure to make sure that the file is closed when you are done with reading it's content. Otherwise you have to close the file manually and most people will forget to do that.

# %%
with astropy.io.fits.open(path2files["FullArray"]) as hdul:
    print(hdul.info())
# Out:
# Filename: ../Data/KELT-11/CH_PR300024_TG000101_TU2020-03-09T14-49-43_SCI_RAW_FullArray_V0101.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  SCI_RAW_FullArray    1 ImageHDU        90   (1024, 1024)   int16 (rescales to uint16)
#   2  SCI_RAW_BlankLeft    1 ImageHDU        82   (8, 1024, 1)   float32
#   3  SCI_RAW_BlankRight    1 ImageHDU        82   (8, 1024, 1)   float32
#   4  SCI_RAW_DarkLeft    1 ImageHDU        82   (16, 1024, 1)   float32
#   5  SCI_RAW_DarkRight    1 ImageHDU        82   (16, 1024, 1)   float32
#   6  SCI_RAW_DarkTop    1 ImageHDU        82   (1024, 3, 1)   float32
#   7  SCI_RAW_OverscanLeft    1 ImageHDU        82   (4, 1024, 1)   float32
#   8  SCI_RAW_OverscanTop    1 ImageHDU        82   (1024, 6, 1)   float32
#   9  SCI_RAW_ImageMetadata    1 BinTableHDU    178   1R x 35C   [1K, 26A, 1D, 1D, 1D, 1K, 26A, 1I, 1J, 1B, 1I, 1I, 5A, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 7E, 1I, 1I]
#  10  SCI_RAW_UnstackedImageMetadata    1 BinTableHDU     96   1R x 12C   [1K, 26A, 1D, 1I, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E]
# None

# %% [markdown]
# However, for exploration of the content of the fits file, it's a bit fastidious since we have to put everything in one cell (encapsulated in this with structure). So we open the file outside of the with structure here.

# %%
hdul = astropy.io.fits.open(path2files["FullArray"])

# %% [markdown]
# HDU stands for Header Data Unit. A Fits file is a collection of HDUs (at least one the PRIMARY HDU). An HDU is composed of a header and data.

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H

# %%
hdul["PRIMARY"].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H

# %% [markdown]
# ## hdul["PRIMARY"].data

# %% [markdown]
# The primary HDU's data is often empty.

# %%
hdul[1].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 1024 / length of data axis 1
# NAXIS2  =                 1024 / length of data axis 2
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# BZERO   =                32768 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# DATE    = '2020-06-16T09:35:41' / creation time of this HDU
# STAMP   = 'visit_combination 12.3.6' / program creating this HDU
# SVN_REV = '21621   '           / svn revision of the software creating this HDU
# EXTNAME = 'SCI_RAW_FullArray'  / extension name
# SCHEMA  = 'SCI_RAW_FullArray.fsd' / filename of schema defining this data struct
# EXT_VER = '12.1.1  '           / version of the data structure
# DATA_LVL= 'L0.5    '           / Level of this data product
# PROC_CHN= 'visit preparation'  / Processing chain creating this data structure
# BUNIT   = 'ADU     '           / Unit of image data
# MRG_MODE= 'image   '           / On-board processing mode of the CCD margins
#
#           / CHEOPS Data Structure
#
# TELESCOP= 'CHEOPS  '           / Telescope's name
# INSTRUME= 'CHEOPS  '           / Instrument's name
# ORIGIN  = 'SOC     '           / Processing site, creating this FITS file
# ARCH_REV=                    1 / Archive revision number
# PROC_NUM=                    1 / Processing Number
# PIPE_VER= 'cn01t-20200615T224519' / Pipeline version
# TIMESYS = 'TT      '           / Time frame system
#
#           / Start and Stop of Validity
#
# V_STRT_U= '2020-03-09T14:49:35.649200' / [TIMESYS=UTC] Start of validity time in
# V_STOP_U= '2020-03-09T14:49:50.649200' / [TIMESYS=UTC] End of validity time in U
# V_STRT_M=     58917.6185744583 / [day] Start of validity time in MJD
# V_STOP_M=     58917.6187480694 / [day] End of validity time in MJD
#
#           / Pass and Visit
#
# PASS_ID = '00000000'           / PassId, when the data were received, 0 if non-a
# PI_NAME = 'Andrea FORTIER'     / Name of the PI of the observing program
# PI_UID  =                 5572 / ID of the PI
# OBS_CAT = 'reference transit'  / Observation Category
# PROGTYPE=                   30 / Type of the program
# PROG_ID =                   24 / Program Id of this type of program
# REQ_ID  =                    1 / Observation request Id of this program
# VISITCTR=                    1 / Visit counter of this target
# OBSID   =              1015981 / Unique identifier of a visit, defined by MPS
# PRP_VST1=                 1825 / [days] Proprietary period, depending on first v
# PRP_VSTN=                 1825 / [days] Proprietary period, depending on last vi
#
#           / Target
#
# TARGNAME= 'KELT-11b'           / Name of the target as provided by the proposal
# SPECTYPE= 'G9V     '           / Spectral type of the target as provided by the
# MAG_V   =               7.8311 / [mag] Brightness of the target in GAIA band
# MAG_VERR=                   0. / [mag] Error of brightness of the target in GAIA
# MAG_CHPS=     7.83824872970581 / [mag] Brightness of the target in CHEOPS band
# MAG_CERR=  0.00039999998989515 / [mag] Error of brightness of the target in CHEO
#
#           / Exposure
#
# T_STRT_O=       41751713501084 / [OBT] OBT of the first measurement
# T_STOP_O=       41751713501084 / [OBT] OBT of the last measurement
# T_STRT_U= '2020-03-09T14:49:43.149200' / [TIMESYS=UTC] UTC of the first measurem
# T_STOP_U= '2020-03-09T14:49:43.149200' / [TIMESYS=UTC] UTC of the last measureme
# T_STRT_M=     58917.6186612639 / [day] MJD of the first measurement
# T_STOP_M=     58917.6186612639 / [day] MJD of the last measurement
# NEXP    =                    1 / Number of co-added measurements
# EXPTIME =                  15. / [sec] Exposure time of the individual exposures
# TEXPTIME=                  15. / [sec] Total exposure time of stacked images
# EXPT_TYP= 'executed'           / Defines the type of EXPTIME and TEXPTIME, eithe
#
#           / Target Coordinates
#
# RA_TARG =     161.707244873047 / RA of the target at epoch of observation
# DEC_TARG=    -9.39902973175049 / DEC of the target at epoch of observation
# EQUINOX =                2000. / Equinox of celestial coord. system
# RADESYS = 'ICRS    '           / Coordinate reference frame for the RA and DEC
#
#           / Image Attributes
#
# ROUNDING=                    0 / number of bits that are rounded off
# NLIN_COR=                    F / on-board nonlinearity correction
# RO_SCRPT=                    4 / id of the CCD readout timing script
# RO_HW   = 'main    '           / used on-board hw: main or redundant
# RO_FREQU=               230000 / [Hz] CCD readout frequency
#
# CHECKSUM= 'PAAWR07VP7AVP75V'   / HDU checksum updated 2020-06-16T09:35:41
# DATASUM = '1884399313'         / data unit checksum updated 2020-06-16T09:35:41

# %%
hdul[1].header["NAXIS"]
# Out:
# 2

# %%
hdul[1].header.comments["NAXIS"]
# Out:
# 'number of data axes'

# %%
hdul[1].header.comments
# Out:
# XTENSION  IMAGE extension
#   BITPIX  number of bits per data pixel
#    NAXIS  number of data axes
#   NAXIS1  length of data axis 1
#   NAXIS2  length of data axis 2
#   PCOUNT  required keyword; must = 0
#   GCOUNT  required keyword; must = 1
#    BZERO  offset data range to that of unsigned short
#   BSCALE  default scaling factor
#     DATE  creation time of this HDU
#    STAMP  program creating this HDU
#  SVN_REV  svn revision of the software creating this HDU
#  EXTNAME  extension name
#   SCHEMA  filename of schema defining this data struct
#  EXT_VER  version of the data structure
# DATA_LVL  Level of this data product
# PROC_CHN  Processing chain creating this data structure
#    BUNIT  Unit of image data
# MRG_MODE  On-board processing mode of the CCD margins
#
#
#
# TELESCOP  Telescope's name
# INSTRUME  Instrument's name
#   ORIGIN  Processing site, creating this FITS file
# ARCH_REV  Archive revision number
# PROC_NUM  Processing Number
# PIPE_VER  Pipeline version
#  TIMESYS  Time frame system
#
#
#
# V_STRT_U  [TIMESYS=UTC] Start of validity time in
# V_STOP_U  [TIMESYS=UTC] End of validity time in U
# V_STRT_M  [day] Start of validity time in MJD
# V_STOP_M  [day] End of validity time in MJD
#
#
#
#  PASS_ID  PassId, when the data were received, 0 if non-a
#  PI_NAME  Name of the PI of the observing program
#   PI_UID  ID of the PI
#  OBS_CAT  Observation Category
# PROGTYPE  Type of the program
#  PROG_ID  Program Id of this type of program
#   REQ_ID  Observation request Id of this program
# VISITCTR  Visit counter of this target
#    OBSID  Unique identifier of a visit, defined by MPS
# PRP_VST1  [days] Proprietary period, depending on first v
# PRP_VSTN  [days] Proprietary period, depending on last vi
#
#
#
# TARGNAME  Name of the target as provided by the proposal
# SPECTYPE  Spectral type of the target as provided by the
#    MAG_V  [mag] Brightness of the target in GAIA band
# MAG_VERR  [mag] Error of brightness of the target in GAIA
# MAG_CHPS  [mag] Brightness of the target in CHEOPS band
# MAG_CERR  [mag] Error of brightness of the target in CHEO
#
#
#
# T_STRT_O  [OBT] OBT of the first measurement
# T_STOP_O  [OBT] OBT of the last measurement
# T_STRT_U  [TIMESYS=UTC] UTC of the first measurem
# T_STOP_U  [TIMESYS=UTC] UTC of the last measureme
# T_STRT_M  [day] MJD of the first measurement
# T_STOP_M  [day] MJD of the last measurement
#     NEXP  Number of co-added measurements
#  EXPTIME  [sec] Exposure time of the individual exposures
# TEXPTIME  [sec] Total exposure time of stacked images
# EXPT_TYP  Defines the type of EXPTIME and TEXPTIME, eithe
#
#
#
#  RA_TARG  RA of the target at epoch of observation
# DEC_TARG  DEC of the target at epoch of observation
#  EQUINOX  Equinox of celestial coord. system
#  RADESYS  Coordinate reference frame for the RA and DEC
#
#
#
# ROUNDING  number of bits that are rounded off
# NLIN_COR  on-board nonlinearity correction
# RO_SCRPT  id of the CCD readout timing script
#    RO_HW  used on-board hw: main or redundant
# RO_FREQU  [Hz] CCD readout frequency
#
# CHECKSUM  HDU checksum updated 2020-06-16T09:35:41
#  DATASUM  data unit checksum updated 2020-06-16T09:35:41

# %%
hdul[1].header["*EXP*"]
# Out:
# NEXP    =                    1 / Number of co-added measurements
# EXPTIME =                  15. / [sec] Exposure time of the individual exposures
# TEXPTIME=                  15. / [sec] Total exposure time of stacked images
# EXPT_TYP= 'executed'           / Defines the type of EXPTIME and TEXPTIME, eithe

# %%
hdul[1].header["*EXP*"].comments
# Out:
#     NEXP  Number of co-added measurements
#  EXPTIME  [sec] Exposure time of the individual exposures
# TEXPTIME  [sec] Total exposure time of stacked images
# EXPT_TYP  Defines the type of EXPTIME and TEXPTIME, eithe

# %%
hdul[1].header.comments["*time*"]
# Out:
#  TIMESYS  Time frame system
#  EXPTIME  [sec] Exposure time of the individual exposures
# TEXPTIME  [sec] Total exposure time of stacked images

# %%
hdul[1].data
# Out:
# array([[564, 566, 562, ..., 553, 559, 564],
#        [569, 548, 565, ..., 558, 562, 571],
#        [565, 568, 566, ..., 562, 704, 570],
#        ...,
#        [570, 574, 565, ..., 756, 560, 550],
#        [578, 570, 568, ..., 578, 559, 564],
#        [574, 577, 579, ..., 564, 574, 574]], dtype=uint16)

# %%
y, x = hdul[1].data.shape
print(y,x)
# Out:
# 1024 1024

# %%
fig, ax = pl.subplots()
im = ax.imshow(hdul[1].data)
pl.colorbar(im);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# You can see that the origin of the pixels numbering is on the upper left, which for images is a bit counter-intuitive.
#
# Also there is a lot of [colormaps](https://matplotlib.org/stable/tutorials/colors/colormaps.html) that you can choose from. In DS9, we have seen that we see much more with a [logarithmic color scale](https://matplotlib.org/stable/tutorials/colors/colormapnorms.html).

# %%
import matplotlib.colors as colors
fig, ax = pl.subplots()

im = ax.imshow(hdul[1].data, origin="lower", cmap=pl.get_cmap("gnuplot"),
          norm=colors.LogNorm(),)
pl.colorbar(im);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# We can obtain mostly same behaviors than in DS9 with [astropy.visualisation](https://docs.astropy.org/en/stable/visualization/normalization.html)

# %%
from astropy.visualization import simple_norm

norm = simple_norm(hdul[1].data, 'log')

im = pl.imshow(hdul[1].data, origin='lower', norm=norm, cmap=pl.get_cmap("gray"))
pl.colorbar(im);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from astropy.visualization import ZScaleInterval

zscale = ZScaleInterval()
zlims = zscale.get_limits(hdul[1].data)
norm = simple_norm(hdul[1].data, 'log', min_cut=zlims[0], max_cut=zlims[1])

im = pl.imshow(hdul[1].data, origin='lower', norm=norm, cmap=pl.get_cmap("gray"))
pl.colorbar(im);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
hdul.close()

# %% [markdown]
# Did you forgot about closing the file ?!

# %% [markdown]
# [Top page](#title_ID)

# %% [markdown]
# ***

# %% [markdown]
# <a id="SubArray_ID"></a>
# # The SubArray images
#
# Now let's have a look at the main data we are going to work with: The SubArray images

# %%
hdul = astropy.io.fits.open(path2files["SubArray"])

# %%
hdul.info()
# Out:
# Filename: ../Data/KELT-11/CH_PR300024_TG000101_TU2020-03-09T14-50-41_SCI_RAW_SubArray_V0101.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  SCI_RAW_SubArray    1 ImageHDU        99   (200, 200, 1535)   int32 (rescales to uint32)
#   2  SCI_RAW_BlankLeft    1 ImageHDU        82   (8, 200, 1535)   float32
#   3  SCI_RAW_BlankRight    1 ImageHDU        82   (8, 200, 1535)   float32
#   4  SCI_RAW_DarkLeft    1 ImageHDU        82   (16, 200, 1535)   float32
#   5  SCI_RAW_DarkRight    1 ImageHDU        82   (16, 200, 1535)   float32
#   6  SCI_RAW_DarkTop    1 ImageHDU        82   (200, 3, 1535)   float32
#   7  SCI_RAW_OverscanLeft    1 ImageHDU        82   (4, 200, 1535)   float32
#   8  SCI_RAW_OverscanTop    1 ImageHDU        82   (200, 6, 1535)   float32
#   9  SCI_RAW_ImageMetadata    1 BinTableHDU    178   1535R x 35C   [1K, 26A, 1D, 1D, 1D, 1K, 26A, 1I, 1J, 1B, 1I, 1I, 5A, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 7E, 1I, 1I]
#  10  SCI_RAW_UnstackedImageMetadata    1 BinTableHDU     96   3070R x 12C   [1K, 26A, 1D, 1I, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E]

# %% [markdown]
# The structure is sensibly the same than the one of the FullArray image, expect that this time, it is a time series (and the size of the images, obviously)

# %%
hdul[1].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    3 / number of data axes
# NAXIS1  =                  200 / length of data axis 1
# NAXIS2  =                  200 / length of data axis 2
# NAXIS3  =                 1535 / length of data axis 3
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# BZERO   =           2147483648 / offset data range to that of unsigned long
# BSCALE  =                    1 / default scaling factor
# DATE    = '2020-06-16T09:35:42' / creation time of this HDU
# STAMP   = 'visit_combination 12.3.6' / program creating this HDU
# SVN_REV = '21621   '           / svn revision of the software creating this HDU
# EXTNAME = 'SCI_RAW_SubArray'   / extension name
# SCHEMA  = 'SCI_RAW_SubArray.fsd' / filename of schema defining this data structu
# EXT_VER = '12.1.1  '           / version of the data structure
# DATA_LVL= 'L0.5    '           / Level of this data product
# PROC_CHN= 'visit preparation'  / Processing chain creating this data structure
# BUNIT   = 'ADU     '           / Unit of image data
# MRG_MODE= 'image   '           / On-board processing mode of the CCD margins
#
#           / CHEOPS Data Structure
#
# TELESCOP= 'CHEOPS  '           / Telescope's name
# INSTRUME= 'CHEOPS  '           / Instrument's name
# ORIGIN  = 'SOC     '           / Processing site, creating this FITS file
# ARCH_REV=                    1 / Archive revision number
# PROC_NUM=                    1 / Processing Number
# PIPE_VER= 'cn01t-20200615T224519' / Pipeline version
# TIMESYS = 'TT      '           / Time frame system
#
#           / Start and Stop of Validity
#
# V_STRT_U= '2020-03-09T14:50:26.385702' / [TIMESYS=UTC] Start of validity time in
# V_STOP_U= '2020-03-10T04:44:49.505211' / [TIMESYS=UTC] End of validity time in U
# V_STRT_M=     58917.6191616864 / [day] Start of validity time in MJD
# V_STOP_M=     58918.1985959399 / [day] End of validity time in MJD
#
#           / Pass and Visit
#
# PASS_ID = '00000000'           / PassId, when the data were received, 0 if non-a
# PI_NAME = 'Andrea FORTIER'     / Name of the PI of the observing program
# PI_UID  =                 5572 / ID of the PI
# OBS_CAT = 'reference transit'  / Observation Category
# PROGTYPE=                   30 / Type of the program
# PROG_ID =                   24 / Program Id of this type of program
# REQ_ID  =                    1 / Observation request Id of this program
# VISITCTR=                    1 / Visit counter of this target
# OBSID   =              1015981 / Unique identifier of a visit, defined by MPS
# PRP_VST1=                 1825 / [days] Proprietary period, depending on first v
# PRP_VSTN=                 1825 / [days] Proprietary period, depending on last vi
#
#           / Target
#
# TARGNAME= 'KELT-11b'           / Name of the target as provided by the proposal
# SPECTYPE= 'G9V     '           / Spectral type of the target as provided by the
# MAG_V   =               7.8311 / [mag] Brightness of the target in GAIA band
# MAG_VERR=                   0. / [mag] Error of brightness of the target in GAIA
# MAG_CHPS=     7.83824872970581 / [mag] Brightness of the target in CHEOPS band
# MAG_CERR=  0.00039999998989515 / [mag] Error of brightness of the target in CHEO
#
#           / Exposure
#
# T_STRT_O=       41751717317672 / [OBT] OBT of the first measurement
# T_STOP_O=       41754996288684 / [OBT] OBT of the last measurement
# T_STRT_U= '2020-03-09T14:50:41.385702' / [TIMESYS=UTC] UTC of the first measurem
# T_STOP_U= '2020-03-10T04:44:34.505211' / [TIMESYS=UTC] UTC of the last measureme
# T_STRT_M=     58917.6193352975 / [day] MJD of the first measurement
# T_STOP_M=     58918.1984223288 / [day] MJD of the last measurement
# NEXP    =                    2 / Number of co-added measurements
# EXPTIME =                  15. / [sec] Exposure time of the individual exposures
# TEXPTIME=                  30. / [sec] Total exposure time of stacked images
# EXPT_TYP= 'executed'           / Defines the type of EXPTIME and TEXPTIME, eithe
#
#           / Target Coordinates
#
# RA_TARG =     161.707244873047 / RA of the target at epoch of observation
# DEC_TARG=    -9.39902973175049 / DEC of the target at epoch of observation
# EQUINOX =                2000. / Equinox of celestial coord. system
# RADESYS = 'ICRS    '           / Coordinate reference frame for the RA and DEC
#
#           / Sub - Array Location on CCD
#
# X_WINOFF=                  715 / [pixel] X offset of the Sub Array image relativ
# Y_WINOFF=                  181 / [pixel] Y offset of the Sub Array image relativ
#
#           / Image Attributes
#
# SHAPE   = 'circular'           / rectangular or circular
# STACKING= 'coadd   '           / on-board stacking of image data
# ROUNDING=                    0 / number of bits that are rounded off
# NLIN_COR=                    F / on-board nonlinearity correction
# RO_SCRPT=                   31 / id of the CCD readout timing script
# RO_HW   = 'main    '           / used on-board hw: main or redundant
# RO_FREQU=               100000 / [Hz] CCD readout frequency
#
# BLANK   =          -2147483648 / NULL value of image
# CHECKSUM= '9A2PGA2N9A2NGA2N'   / HDU checksum updated 2020-06-16T09:40:08
# DATASUM = '2463215871'         / data unit checksum updated 2020-06-16T09:40:08

# %% [markdown]
# Let's load and plot the data

# %%
im_TS = hdul[1].data
t,y,x = im_TS.shape

# %%
idx = 100

norm = simple_norm(im_TS, 'log')

im = pl.imshow(im_TS[idx], origin='lower', norm=norm, cmap=pl.get_cmap("gray"))
pl.colorbar(im);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# In order to reduce the data, we will need to access the CCD margins

# %%
hdul["SCI_RAW_DarkLeft"].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    3 / number of data axes
# NAXIS1  =                   16 / length of data axis 1
# NAXIS2  =                  200 / length of data axis 2
# NAXIS3  =                 1535 / length of data axis 3
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# DATE    = '2020-06-16T09:35:47' / creation time of this HDU
# STAMP   = 'visit_combination 12.3.6' / program creating this HDU
# SVN_REV = '21621   '           / svn revision of the software creating this HDU
# EXTNAME = 'SCI_RAW_DarkLeft'   / extension name
# SCHEMA  = 'SCI_RAW_DarkLeft.fsd' / filename of schema defining this data structu
# EXT_VER = '12.1.1  '           / version of the data structure
# DATA_LVL= 'L0.5    '           / Level of this data product
# PROC_CHN= 'visit preparation'  / Processing chain creating this data structure
# BUNIT   = 'ADU     '           / Unit of image data
#
#           / CHEOPS Data Structure
#
# TELESCOP= 'CHEOPS  '           / Telescope's name
# INSTRUME= 'CHEOPS  '           / Instrument's name
# ORIGIN  = 'SOC     '           / Processing site, creating this FITS file
# ARCH_REV=                    1 / Archive revision number
# PROC_NUM=                    1 / Processing Number
# PIPE_VER= 'cn01t-20200615T224519' / Pipeline version
# TIMESYS = 'TT      '           / Time frame system
#
#           / Start and Stop of Validity
#
# V_STRT_U= '2020-03-09T14:50:26.385702' / [TIMESYS=UTC] Start of validity time in
# V_STOP_U= '2020-03-10T04:44:49.505211' / [TIMESYS=UTC] End of validity time in U
# V_STRT_M=     58917.6191616864 / [day] Start of validity time in MJD
# V_STOP_M=     58918.1985959399 / [day] End of validity time in MJD
#
#           / Pass and Visit
#
# PASS_ID = '00000000'           / PassId, when the data were received, 0 if non-a
# PI_NAME = 'Andrea FORTIER'     / Name of the PI of the observing program
# PI_UID  =                 5572 / ID of the PI
# OBS_CAT = 'reference transit'  / Observation Category
# PROGTYPE=                   30 / Type of the program
# PROG_ID =                   24 / Program Id of this type of program
# REQ_ID  =                    1 / Observation request Id of this program
# VISITCTR=                    1 / Visit counter of this target
# OBSID   =              1015981 / Unique identifier of a visit, defined by MPS
# PRP_VST1=                 1825 / [days] Proprietary period, depending on first v
# PRP_VSTN=                 1825 / [days] Proprietary period, depending on last vi
#
#           / Exposure
#
# T_STRT_O=       41751717317672 / [OBT] OBT of the first measurement
# T_STOP_O=       41754996288684 / [OBT] OBT of the last measurement
# T_STRT_U= '2020-03-09T14:50:41.385702' / [TIMESYS=UTC] UTC of the first measurem
# T_STOP_U= '2020-03-10T04:44:34.505211' / [TIMESYS=UTC] UTC of the last measureme
# T_STRT_M=     58917.6193352975 / [day] MJD of the first measurement
# T_STOP_M=     58918.1984223288 / [day] MJD of the last measurement
# NEXP    =                    2 / Number of co-added measurements
# EXPTIME =                  15. / [sec] Exposure time of the individual exposures
# TEXPTIME=                  30. / [sec] Total exposure time of stacked images
# EXPT_TYP= 'executed'           / Defines the type of EXPTIME and TEXPTIME, eithe
#
#           / Sub - Array
#
# Y_WINOFF=                  181 / [pixel] Y offset of the margin image relative t
#
#           / Description of CCD Margin Data
#
# STACKING= 'coadd   '           / on-board stacking of image data
# MRG_PROC= 'image   '           / on-board processing of CCD margin: image, row c
# MRG_DTY1= 'N/A     '           / Type of data in 1. column in image
# MRG_DTY2= 'N/A     '           / Type of data in 2. column in image
# MRG_DTY3= 'N/A     '           / Type of data in 3. column in image
# MRG_DTY4= 'N/A     '           / Type of data in 4. column in image
#
#           / Image Attributes
#
# ROUNDING=                    0 / number of bits that are rounded off
# NLIN_COR=                    F / on-board nonlinearity correction
#
# CHECKSUM= '9RVAGOS89OSAGOS7'   / HDU checksum updated 2020-06-16T09:35:48
# DATASUM = '1385122877'         / data unit checksum updated 2020-06-16T09:35:48

# %%
dark_left = hdul["SCI_RAW_DarkLeft"].data
dark_left.shape
# Out:
# (1535, 200, 16)

# %%
zscale = ZScaleInterval()
zlims = zscale.get_limits(dark_left)
norm = simple_norm(dark_left, 'linear', min_cut=zlims[0], max_cut=zlims[1])

im = pl.imshow(dark_left[10], origin='lower', norm=norm, cmap=pl.get_cmap("gray"))
pl.colorbar(im);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# We proceed the same way to access all CCD margins.
#
# Finally, we might need to access additional information about these images. At least the time at which each images has been observed. This information is stored in the metadata.

# %%
hdul["SCI_RAW_ImageMetadata"].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  216 / width of table in bytes
# NAXIS2  =                 1535 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   35 / number of fields in each row
# TTYPE1  = 'OBT_TIME'           / On board time, middle of the measurements
# TFORM1  = '1K      '           / format of field
# TUNIT1  = 'OBT     '           / Unit of column OBT_TIME
# TTYPE2  = 'UTC_TIME'           / UTC time, middle of the measurements
# TFORM2  = '26A     '           / format of field
# TUNIT2  = 'TIMESYS=UTC'        / Unit of column UTC_TIME
# TTYPE3  = 'MJD_TIME'           / Modified Julian Day, middle of the measurements
# TFORM3  = '1D      '           / format of field
# TUNIT3  = 'day     '           / Unit of column MJD_TIME
# TTYPE4  = 'LOS_TO_SUN_ANGLE'   / Angle between target and Sun
# TFORM4  = '1D      '           / format of field
# TUNIT4  = 'deg     '           / Unit of column LOS_TO_SUN_ANGLE
# TTYPE5  = 'LOS_TO_MOON_ANGLE'  / Angle between target and Moon
# TFORM5  = '1D      '           / format of field
# TUNIT5  = 'deg     '           / Unit of column LOS_TO_MOON_ANGLE
# TTYPE6  = 'OBT_CE_TIME'        / OBT when the compression entity was build
# TFORM6  = '1K      '           / format of field
# TUNIT6  = 'OBT     '           / Unit of column OBT_CE_TIME
# TTYPE7  = 'UTC_CE_TIME'        / UTC when the compression entity was build
# TFORM7  = '26A     '           / format of field
# TUNIT7  = 'TIMESYS=UTC'        / Unit of column UTC_CE_TIME
# TTYPE8  = 'CE_COUNTER'         / image counter per visit
# TFORM8  = '1I      '           / format of field
# TZERO8  =                32768 / offset for unsigned integers
# TSCAL8  =                    1 / data are not scaled
# TTYPE9  = 'CE_SIZE '           / Size in byte of the compressed CE
# TFORM9  = '1J      '           / format of field
# TZERO9  =           2147483648 / offset for unsigned integers
# TSCAL9  =                    1 / data are not scaled
# TTYPE10 = 'CE_INTEGRITY'       / 1: a problem occurred during data processing
# TFORM10 = '1B      '           / format of field
# TTYPE11 = 'CCD_TIMING_SCRIPT'  / Identifier of the currently used CCD timing scr
# TFORM11 = '1I      '           / format of field
# TZERO11 =                32768 / offset for unsigned integers
# TSCAL11 =                    1 / data are not scaled
# TTYPE12 = 'PIX_DATA_OFFSET'    / Digital bias added by the SEM
# TFORM12 = '1I      '           / format of field
# TZERO12 =                32768 / offset for unsigned integers
# TSCAL12 =                    1 / data are not scaled
# TUNIT12 = 'ADU     '           / Unit of column PIX_DATA_OFFSET
# TTYPE13 = 'HK_SOURCE'          / HK data from HK TM packets (hk tm) or from CE i
# TFORM13 = '5A      '           / format of field
# TTYPE14 = 'HK_VOLT_FEE_VOD'    / FEE voltage to CCD (DAC output)
# TFORM14 = '1E      '           / format of field
# TUNIT14 = 'V       '           / Unit of column HK_VOLT_FEE_VOD
# TTYPE15 = 'HK_VOLT_FEE_VRD'    / FEE voltage to CCD (DAC output)
# TFORM15 = '1E      '           / format of field
# TUNIT15 = 'V       '           / Unit of column HK_VOLT_FEE_VRD
# TTYPE16 = 'HK_VOLT_FEE_VOG'    / FEE voltage to CCD
# TFORM16 = '1E      '           / format of field
# TUNIT16 = 'V       '           / Unit of column HK_VOLT_FEE_VOG
# TTYPE17 = 'HK_VOLT_FEE_VSS'    / FEE voltage to CCD (DAC output)
# TFORM17 = '1E      '           / format of field
# TUNIT17 = 'V       '           / Unit of column HK_VOLT_FEE_VSS
# TTYPE18 = 'HK_TEMP_FEE_CCD'    / FPA/CCD (two sensors for main and redundant cha
# TFORM18 = '1E      '           / format of field
# TUNIT18 = 'degC    '           / Unit of column HK_TEMP_FEE_CCD
# TTYPE19 = 'HK_TEMP_FEE_ADC'    / ADC/analog chain area (two sensors on one PCB f
# TFORM19 = '1E      '           / format of field
# TUNIT19 = 'degC    '           / Unit of column HK_TEMP_FEE_ADC
# TTYPE20 = 'HK_TEMP_FEE_BIAS'   / BIAS voltage area (two sensors on one PCB for m
# TFORM20 = '1E      '           / format of field
# TUNIT20 = 'degC    '           / Unit of column HK_TEMP_FEE_BIAS
# TTYPE21 = 'ADC_N5V '           / Value from resistor measurement
# TFORM21 = '1E      '           / format of field
# TUNIT21 = 'V       '           / Unit of column ADC_N5V
# TTYPE22 = 'ADC_TEMP1'          / Value from thermistor
# TFORM22 = '1E      '           / format of field
# TUNIT22 = 'degC    '           / Unit of column ADC_TEMP1
# TTYPE23 = 'thermAft_1'         / Temperature acquired from aft thermistor 1
# TFORM23 = '1E      '           / format of field
# TUNIT23 = 'degC    '           / Unit of column thermAft_1
# TTYPE24 = 'thermAft_2'         / Temperature acquired from aft thermistor 2
# TFORM24 = '1E      '           / format of field
# TUNIT24 = 'degC    '           / Unit of column thermAft_2
# TTYPE25 = 'thermAft_3'         / Temperature acquired from aft thermistor 3
# TFORM25 = '1E      '           / format of field
# TUNIT25 = 'degC    '           / Unit of column thermAft_3
# TTYPE26 = 'thermAft_4'         / Temperature acquired from aft thermistor 4
# TFORM26 = '1E      '           / format of field
# TUNIT26 = 'degC    '           / Unit of column thermAft_4
# TTYPE27 = 'thermFront_1'       / Temperature acquired from front thermistor 1
# TFORM27 = '1E      '           / format of field
# TUNIT27 = 'degC    '           / Unit of column thermFront_1
# TTYPE28 = 'thermFront_2'       / Temperature acquired from front thermistor 2
# TFORM28 = '1E      '           / format of field
# TUNIT28 = 'degC    '           / Unit of column thermFront_2
# TTYPE29 = 'thermFront_3'       / Temperature acquired from front thermistor 3
# TFORM29 = '1E      '           / format of field
# TUNIT29 = 'degC    '           / Unit of column thermFront_3
# TTYPE30 = 'thermFront_4'       / Temperature acquired from front thermistor 4
# TFORM30 = '1E      '           / format of field
# TUNIT30 = 'degC    '           / Unit of column thermFront_4
# TTYPE31 = 'HEADER_COMPR'       / compression factor of header
# TFORM31 = '1E      '           / format of field
# TTYPE32 = 'STACKED_COMPR'      / compression factor of stacked frame
# TFORM32 = '1E      '           / format of field
# TTYPE33 = 'MARGINS_COMPR'      / compression factor of margins
# TFORM33 = '7E      '           / format of field
# TTYPE34 = 'LEFT_DARK_COL_MASK' / defines the selected/deselected left dark colum
# TFORM34 = '1I      '           / format of field
# TZERO34 =                32768 / offset for unsigned integers
# TSCAL34 =                    1 / data are not scaled
# TTYPE35 = 'RIGHT_DARK_COL_MASK' / defines the selected/deselected right dark col
# TFORM35 = '1I      '           / format of field
# TZERO35 =                32768 / offset for unsigned integers
# TSCAL35 =                    1 / data are not scaled
# DATE    = '2020-06-16T09:35:49' / creation time of this HDU
# STAMP   = 'visit_combination 12.3.6' / program creating this HDU
# SVN_REV = '21621   '           / svn revision of the software creating this HDU
# TNULL1  =                   -1 / NULL value of column OBT_TIME
# TNULL6  =                   -1 / NULL value of column OBT_CE_TIME
# EXTNAME = 'SCI_RAW_ImageMetadata' / extension name
# SCHEMA  = 'SCI_RAW_ImageMetadata.fsd' / filename of schema defining this data st
# EXT_VER = '12.1.1  '           / version of the data structure
# DATA_LVL= 'L0.5    '           / Level of this data product
# PROC_CHN= 'visit preparation'  / Processing chain creating this data structure
#
#           / CHEOPS Data Structure
#
# TELESCOP= 'CHEOPS  '           / Telescope's name
# INSTRUME= 'CHEOPS  '           / Instrument's name
# ORIGIN  = 'SOC     '           / Processing site, creating this FITS file
# ARCH_REV=                    1 / Archive revision number
# PROC_NUM=                    1 / Processing Number
# PIPE_VER= 'cn01t-20200615T224519' / Pipeline version
# TIMESYS = 'TT      '           / Time frame system
#
#           / Start and Stop of Validity
#
# V_STRT_U= '2020-03-09T14:50:26.385702' / [TIMESYS=UTC] Start of validity time in
# V_STOP_U= '2020-03-10T04:44:49.505211' / [TIMESYS=UTC] End of validity time in U
# V_STRT_M=     58917.6191616864 / [day] Start of validity time in MJD
# V_STOP_M=     58918.1985959399 / [day] End of validity time in MJD
#
#           / Pass and Visit
#
# PASS_ID = '00000000'           / PassId, when the data were received, 0 if non-a
# PI_NAME = 'Andrea FORTIER'     / Name of the PI of the observing program
# PI_UID  =                 5572 / ID of the PI
# OBS_CAT = 'reference transit'  / Observation Category
# PROGTYPE=                   30 / Type of the program
# PROG_ID =                   24 / Program Id of this type of program
# REQ_ID  =                    1 / Observation request Id of this program
# VISITCTR=                    1 / Visit counter of this target
# OBSID   =              1015981 / Unique identifier of a visit, defined by MPS
# PRP_VST1=                 1825 / [days] Proprietary period, depending on first v
# PRP_VSTN=                 1825 / [days] Proprietary period, depending on last vi
#
#           / Target
#
# TARGNAME= 'KELT-11b'           / Name of the target as provided by the proposal
# SPECTYPE= 'G9V     '           / Spectral type of the target as provided by the
# MAG_V   =               7.8311 / [mag] Brightness of the target in GAIA band
# MAG_VERR=                   0. / [mag] Error of brightness of the target in GAIA
# MAG_CHPS=     7.83824872970581 / [mag] Brightness of the target in CHEOPS band
# MAG_CERR=  0.00039999998989515 / [mag] Error of brightness of the target in CHEO
#
#           / Compression Entity Header
#
# IFSW_VER=                28171 / Version of the IFSW
# ACQ_MODE=                    4 / Acquisition mode 1: DUMP 2: DIGIT 3: FULL
# RD_MODE = 'faint   '           / Readout mode: faint, bright ultrabright, full f
# OVERSAMP=                    F / Oversampling mode if true than averaging of sev
# F_SOURCE=                    0 / Frame source 0: CCD 1: PATTERN 2:SIMULATION
# REPETIT =     15.0240001678467 / [sec] Repetition Period see also REPT_TYP
# REPT_TYP= 'executed'           / Defines the type of REPETIT, either commanded o
#
# CHECKSUM= 'kPZJlNXJkNXJkNXJ'   / HDU checksum updated 2020-06-16T09:40:02
# DATASUM = '2319508865'         / data unit checksum updated 2020-06-16T09:40:02

# %%
table = hdul["SCI_RAW_ImageMetadata"].data
print(f"The length of the table is {len(table)}")
print(f"It's columns are {table.columns}")
# Out:
# The length of the table is 1535
# It's columns are ColDefs(
#     name = 'OBT_TIME'; format = '1K'; unit = 'OBT'; null = -1
#     name = 'UTC_TIME'; format = '26A'; unit = 'TIMESYS=UTC'
#     name = 'MJD_TIME'; format = '1D'; unit = 'day'
#     name = 'LOS_TO_SUN_ANGLE'; format = '1D'; unit = 'deg'
#     name = 'LOS_TO_MOON_ANGLE'; format = '1D'; unit = 'deg'
#     name = 'OBT_CE_TIME'; format = '1K'; unit = 'OBT'; null = -1
#     name = 'UTC_CE_TIME'; format = '26A'; unit = 'TIMESYS=UTC'
#     name = 'CE_COUNTER'; format = '1I'; bscale = 1; bzero = 32768
#     name = 'CE_SIZE'; format = '1J'; bscale = 1; bzero = 2147483648
#     name = 'CE_INTEGRITY'; format = '1B'
#     name = 'CCD_TIMING_SCRIPT'; format = '1I'; bscale = 1; bzero = 32768
#     name = 'PIX_DATA_OFFSET'; format = '1I'; unit = 'ADU'; bscale = 1; bzero = 32768
#     name = 'HK_SOURCE'; format = '5A'
#     name = 'HK_VOLT_FEE_VOD'; format = '1E'; unit = 'V'
#     name = 'HK_VOLT_FEE_VRD'; format = '1E'; unit = 'V'
#     name = 'HK_VOLT_FEE_VOG'; format = '1E'; unit = 'V'
#     name = 'HK_VOLT_FEE_VSS'; format = '1E'; unit = 'V'
#     name = 'HK_TEMP_FEE_CCD'; format = '1E'; unit = 'degC'
#     name = 'HK_TEMP_FEE_ADC'; format = '1E'; unit = 'degC'
#     name = 'HK_TEMP_FEE_BIAS'; format = '1E'; unit = 'degC'
#     name = 'ADC_N5V'; format = '1E'; unit = 'V'
#     name = 'ADC_TEMP1'; format = '1E'; unit = 'degC'
#     name = 'thermAft_1'; format = '1E'; unit = 'degC'
#     name = 'thermAft_2'; format = '1E'; unit = 'degC'
#     name = 'thermAft_3'; format = '1E'; unit = 'degC'
#     name = 'thermAft_4'; format = '1E'; unit = 'degC'
#     name = 'thermFront_1'; format = '1E'; unit = 'degC'
#     name = 'thermFront_2'; format = '1E'; unit = 'degC'
#     name = 'thermFront_3'; format = '1E'; unit = 'degC'
#     name = 'thermFront_4'; format = '1E'; unit = 'degC'
#     name = 'HEADER_COMPR'; format = '1E'
#     name = 'STACKED_COMPR'; format = '1E'
#     name = 'MARGINS_COMPR'; format = '7E'
#     name = 'LEFT_DARK_COL_MASK'; format = '1I'; bscale = 1; bzero = 32768
#     name = 'RIGHT_DARK_COL_MASK'; format = '1I'; bscale = 1; bzero = 32768
# )

# %% [markdown]
# The meaning of the format can be found [here](https://docs.astropy.org/en/stable/io/fits/usage/table.html).
# The time is provided in different format. The format that we are going to use is "MJD" for Modified Julian data. It's the BJD_TDB - 2 400 000.

# %%
table['MJD_TIME'].shape
# Out:
# (1535,)

# %% [markdown]
# [Top page](#title_ID)

# %% [markdown]
# ***

# %% [markdown]
# <a id="Imagette_ID"></a>
# # The Imagette
#
# You can now explore the imagettes yourself using the same commands.
